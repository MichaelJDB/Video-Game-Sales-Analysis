# %% [markdown]
# # **Exploratoy Data Analysis With Video Game Sales**

# %% [markdown]
# ### **Description:**
#
# I will be analysing video game sales to locate trends across regions, genres and platforms. I will create visualisations to show the top 5 of these selected columns. Region - Bar Chart, Genres - Treemap, Platforms - Boxplot. Once I have created these I can complete my analysis on the datset.

# %% [markdown]
# ### **Objectives**
#
# * Load dataset downloaded from Kaggle
# * Transform datset
# * Store tranformed data for analysis
# * Identify key factors with video game sales
# * Create Hypotheses
# * Develop visualisations from the data
# * Build (machine learning graphs) to predict....

# %% [markdown]
# ### **Inputs**

# %% [markdown]
# * Dataset: VideoGamesSales.csv @ https://www.kaggle.com/datasets/thedevastator/global-video-game-sales-and-reviews/data
# * Libraries: Pandas, NumPy, Seaborn, Maplotlib, Scikit-learn

# %% [markdown]
# ### **Outputs**

# %% [markdown]
# * **Clean data:** New processed data csv file which can now be used for analysis - vgsales_cleaned.csv
# * **Data types**
# * **Locate and change missing values**
# * **Check for duplicates**
# * **Consideration with data privacy and ethics**
# * **Visualisations**
# * **Data Analysis**
# * **Compare statistics**
# * **Create reports**

# %% [markdown]
# Import all the necessary libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as snas
import plotly.express as px

# %% [markdown]
# Load the data

# %%
df = pd.read_csv('Data/vgsales_cleaned.csv')
df.head()
# Out:
#    index  Rank         Game Title Platform    Year     Genre Publisher  \
# 0      0     1         Wii Sports      Wii  2006.0    Sports  Nintendo
# 1      1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo
# 2      2     3     Mario Kart Wii      Wii  2008.0    Racing  Nintendo
# 3      3     4  Wii Sports Resort      Wii  2009.0    Sports  Nintendo
# 4      4     5             Tetris       GB  1989.0    Puzzle  Nintendo
#
#    North America  Europe  Japan  Rest of World  Global  Review
# 0          40.43   28.39   3.77           8.54   81.12   76.28
# 1          29.08    3.58   6.81           0.77   40.24   91.00
# 2          14.50   12.22   3.63           3.21   33.55   82.07
# 3          14.82   10.51   3.18           3.01   31.52   82.65
# 4          23.20    2.26   4.22           0.58   30.26   88.00

# %% [markdown]
# This dataset focuses on video game sales information which is:
# * Rank - ranking of games based on their global sales volume
# * Game Title - Name of the game
# * Platform - The platform that the game is accessible on
# * Year - When the game was released
# * Genre - What type of game it is like action, puzzle, etc
# * Publisher - Which company created/ owns the game
# * North America, Europe, Japan, Rest of World, Global (units in millions sold in each place)
# * Review - The score of the game 1-10

# %% [markdown]
# # **Visualisations:**
#
# **Bar Chart - Genres**
#
# Bar Chart, Genres - Treemap, Platforms - Boxplot. Once I have created these I can complete my analysis on the datset.

# %%
import pandas as pd
data = pd.read_csv('Data/vgsales_cleaned.csv')

# %%
top_genres = data.groupby('Genre')['Global'].sum().sort_values(ascending=False).head(5)

# %%
import matplotlib.pyplot as plt
top_genres.plot(kind='bar', color='blue')
plt.title('Top 5 Video Game Genres by Global Sales')
plt.xlabel('Genre')
plt.ylabel('Global Sales (in millions)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This bar chat shows which genres of video games sold the most units worldwide with 'Sports' being the most sold genre. There isn't a huge difference between these five genres which indicates that they are all successful in the video game market and can be great for targeting genres in the future of game development. However, if we wanted to be more precise we could examine the reviews per genre to see if people are really enjoying these video game genres.

# %%
# Load the dataset
data = pd.read_csv('Data/vgsales_cleaned.csv')

# Group by Genre and calculate average review score
avg_reviews = data.groupby('Genre')['Review'].mean().sort_values(ascending=False)

# Plot the bar chart
plt.figure(figsize=(10, 6))
avg_reviews.plot(kind='bar', color='green')
plt.title('Average Review Score by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Review Score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This bar chart shows the difference between popularity and critics which helps with those that are enjoyed by the consumers rather than those that are mass purchased. This is useful as it provides companies to see their video game genres are being enjoyed and can continue with creating similar games or select features from previous games that make up those genres to carry over to new ones to target their audiences.
