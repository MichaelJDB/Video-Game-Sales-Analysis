# %% [markdown]
# # **Video Game Sales Analysis**
#
# ## **Objective**
#
# I will be exploring the world of video games by analysing and cleaning data using Python libraries in order to uncover insights, exam trends and create clear and easy to read visualisation. Through a combination of Python libraries I will uncover the popularity of video games, locate any trends in the data and present my results in suitable visualisations.
#
# ## **Libraries**
#
# * **Pandas:** Data manipulation and analysis, offers the ability to clean and transform data.
# * **NumPy:** Numerical libarary that allows a range of mathematical functions.
#
#
#
# //

# %% [markdown]
# ### Importing And Viewing The Dataset
#
# I will be importing the dataset csv file so that I can view and check for any outliers in
# the data.

# %%
#Import the required libraries
import pandas as pd
import numpy as np

#Display dataset for viewing
data = pd.read_csv('Data/vgsales.csv')

# %%
import os 
print(os.getcwd())
# Out:
# e:\GitHub\Video-Game-Sales-Analysis\jupyter_notebooks

# %%
print(os.listdir())
# Out:
# ['Notebook_Template.ipynb', 'VG.ipynb']
