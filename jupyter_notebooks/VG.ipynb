# %% [markdown]
# # **Data Cleaning**
#
# ## **Libraries**
#
# * **Pandas:** Data manipulation and analysis, offers the ability to clean and transform data.
# * **NumPy:** Numerical libarary that allows a range of mathematical functions.
# * **seaborn:** Provides a detailed interface for stastical visuals.
# * **matplotlib:** Provides a range of visual options, simple or complex figures.
#
# Through the use of these libraries I can create evidence for all hypotheses regarding the video game sales from 1980 to present.

# %% [markdown]
# ### Importing And Viewing The Dataset
#
# I will be importing the dataset csv file so that I can view and check for any outliers in
# the data.

# %%
#Import the required libraries
import pandas as pd
import numpy as np

#Display dataset for viewing
data = pd.read_csv('Data/vgsales.csv')
data
# Out:
#       index  Rank                        Game Title Platform    Year  \
# 0         0     1                        Wii Sports      Wii  2006.0
# 1         1     2                 Super Mario Bros.      NES  1985.0
# 2         2     3                    Mario Kart Wii      Wii  2008.0
# 3         3     4                 Wii Sports Resort      Wii  2009.0
# 4         4     5                            Tetris       GB  1989.0
# ...     ...   ...                               ...      ...     ...
# 1902   1902  1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004.0
# 1903   1903  1904              Xenoblade Chronicles      Wii  2010.0
# 1904   1904  1905                     SingStar Abba      PS3  2008.0
# 1905   1905  1906    FIFA Soccer World Championship      PS2  2000.0
# 1906   1906  1907        WWE SmackDown vs. Raw 2011     X360  2010.0
#
#              Genre                    Publisher  North America  Europe  Japan  \
# ...

# %%
#Check the column data types.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1907 entries, 0 to 1906
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1907 non-null   int64
#  1   Rank           1907 non-null   int64
#  2   Game Title     1907 non-null   object
#  3   Platform       1907 non-null   object
#  4   Year           1878 non-null   float64
#  5   Genre          1907 non-null   object
#  6   Publisher      1905 non-null   object
#  7   North America  1907 non-null   float64
#  8   Europe         1907 non-null   float64
#  9   Japan          1907 non-null   float64
#  10  Rest of World  1907 non-null   float64
#  11  Global         1907 non-null   float64
#  12  Review         1907 non-null   float64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 193.8+ KB

# %%
#Check for any missing values in the dataset.
data.isnull().sum()
# Out:
# index             0
# Rank              0
# Game Title        0
# Platform          0
# Year             29
# Genre             0
# Publisher         2
# North America     0
# Europe            0
# Japan             0
# Rest of World     0
# Global            0
# Review            0
# dtype: int64

# %% [markdown]
# There appears to be two missing values in the dataset I will drop these for now unless they are critical with my analysis later.

# %%
#Remove rows with missin 'Year' values.
data = data.dropna(subset=['Year'])

# %%
#Check for any missing values in the dataset.
data.isnull().sum()
# Out:
# index            0
# Rank             0
# Game Title       0
# Platform         0
# Year             0
# Genre            0
# Publisher        0
# North America    0
# Europe           0
# Japan            0
# Rest of World    0
# Global           0
# Review           0
# dtype: int64

# %%
#Check for duplicates
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are no duplicates in the dataset.

# %%
#Statisical summary of the dataset.
data.describe()
# Out:
#              index         Rank         Year  North America       Europe  \
# count  1878.000000  1878.000000  1878.000000    1878.000000  1878.000000
# mean    950.716720   951.716720  2003.766773       1.262109     0.710517
# std     550.234127   550.234127     5.895369       1.967797     1.155922
# min       0.000000     1.000000  1983.000000       0.000000     0.000000
# 25%     474.250000   475.250000  2000.000000       0.510000     0.230000
# 50%     950.500000   951.500000  2005.000000       0.820000     0.440000
# 75%    1426.750000  1427.750000  2008.000000       1.377500     0.820000
# max    1906.000000  1907.000000  2012.000000      40.430000    28.390000
#
#              Japan  Rest of World       Global       Review
# count  1878.000000    1878.000000  1878.000000  1878.000000
# mean      0.320980       0.207055     2.500532    79.038243
# std       0.729295       0.345141     3.587041    10.652957
# min       0.000000       0.000000     0.830000    30.500000
# ...

# %% [markdown]
# The stastics of the dataset seems to standards.

# %%
#Check for any 'Year' values that are out of the data range.
data[(data['Year'] < 1980) | (data['Year'] > 2024)]
# Out:
# Empty DataFrame
# Columns: [index, Rank, Game Title, Platform, Year, Genre, Publisher, North America, Europe, Japan, Rest of World, Global, Review]
# Index: []

# %% [markdown]
# There are no years out of the data's range.

# %% [markdown]
# I am please with this data cleaning and I will now create a new data file.
